# %% [markdown]
# <h1 style="color:blue" align="center">Machine Learning : Linear Regression With One Variable</h1>

# %% [markdown]
# **Problem Statement**: Build a machine learning model that can predict home prices based on square feet area based on following.

# %% [markdown]
# <img src="numpy_data.png" style="width:50%" />

# %% [markdown]
# You might remember about linear equation from your school days math class. Home prices can be presented as following equation,
#
# home price = m * (area) + b

# %% [markdown]
# <img src="linear_equation.png" style="width:50%"/>

# %% [markdown]
# <h2 style="color:blue;">Import numpy, matplotlib and LinearRegression from sklearn</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h2 style="color:blue;">Define the Sample Data</h2>

# %%
# Sample data
# X = size of the house (in square feet)
# y = price of the house (in Rs in Lakhs )
X = np.array([[300], [400], [500], [600], [700]])
print(X)
y = np.array([150, 200, 250, 300, 350])
print(y)
# Out:
# [[300]
#  [400]
#  [500]
#  [600]
#  [700]]
# [150 200 250 300 350]

# %%
# Create a linear regression model
model = LinearRegression()

# %%
# Train the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predict
predicted = model.predict(X)

# %%
# Print model parameters
print("Slope (Coefficient):", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Slope (Coefficient): [0.5]
# Intercept: 1.4210854715202004e-13

# %%
# Plotting
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, predicted, color='red', linewidth=2, label='Regression line')
plt.xlabel("Size (sq ft)")
plt.ylabel("Price (in Lakhs)")
plt.title("House Price Prediction")
plt.legend()
plt.grid(True)
plt.show()

# %%
X_test = np.array([[320],[455]])
# Predict
predicted = model.predict(X_test)
print(predicted)
# Out:
# [160.  227.5]

# %%
plt.plot(X, y, color='red', linewidth=2, label='Regression line')
plt.scatter(X, y, color='blue', label='Actual data')
plt.scatter(X_test, predicted, color='green', label='test data')

plt.xlabel("Size (sq ft)")
plt.ylabel("Price (in Lakhs)")
plt.title("House Price Prediction")
plt.legend()
plt.grid(True)
plt.show()
