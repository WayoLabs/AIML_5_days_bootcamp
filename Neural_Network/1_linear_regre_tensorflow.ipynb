# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
X = np.array([300, 400, 500, 600, 700], dtype=float)
y = np.array([150, 200, 250, 300, 350], dtype=float)
X
# Out:
# array([300., 400., 500., 600., 700.])

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])
])
# Out:
# c:\Users\Kuldeep\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X, y, epochs=500, verbose=0)

# %%
X_test = np.array([650], dtype=float)
prediction = model.predict(X_test)
print("Predicted price for 650 sq ft:", prediction[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted price for 650 sq ft: 322.23642

# %%
plt.plot(history.history['loss'])
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
